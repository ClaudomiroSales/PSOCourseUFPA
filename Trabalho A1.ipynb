# %% [markdown]
# Em um novo arquivo Jupyter, copiar partes do código do Matheus que forem necessárias para otimizar as duas funções de teste abaixo:

# %% [markdown]
# - Rastrigin

# %% [markdown]
# - Rosenbrock_function https://en.wikipedia.org/wiki/Rosenbrock_function
# TF2 abaixo

# %% [markdown]
# Trabalhem com duas dimensões em ambas as funções.

# %%
pathFileImages = 'C:/Users/claud/Dropbox/RepoGit/Disciplina/PSO/TrabalhoA1/'


from IPython.display import Image
from IPython.display import HTML

# %%
Image(filename = pathFileImages + 'TestFuction.png')

# %%
def tf1(x):
    D = len(x)
    soma = 0
    for i in range(D):
        soma += x[i]**2

    return soma

def tf2(x):
    D = len(x)
    soma = 0
    for i in range(D-1):
        soma += 100*(x[i+1] - x[i]**2)**2 + (1 - x[i])**2

    return soma

def tf3(x):
    D = len(x)
    soma = 0
    for i in range(D):
        soma += x[i]**2 - 10*np.cos(2*np.pi*x[i])

    return 10*D + soma

def tf4(x):
    D = len(x)
    soma = 0
    produto = 1
    for i in range(D):
        soma += x[i]**2
        produto *= np.cos(x[i]/np.sqrt(i+1))

    return 1 + 1/4000*soma - produto

def tf5(x):
    D = len(x)
    soma1 = 0
    soma2 = 0
    for i in range(D):
        soma1 += x[i]**2
        soma2 += np.cos(2*np.pi*x[i])

    return -20*np.exp(-0.2*np.sqrt(1/D*soma1)) - np.exp(1/D*soma2) + 20 + np.e

def tf6(x):
    D = len(x)
    soma = 0
    for i in range(D):
        soma += (i+1)*x[i]**2

    return soma

def tf7(x):
    return 0.5 + (np.sin(x[0]**2 - x[1]**2)**2 - 0.5)/(1+0.001*(x[0]**2+x[1]**2))**2

def tf8(x):
    D = len(x)
    soma = 0
    for i in range(D):
        soma += np.abs(x[i]*np.sin(x[i]) + 0.1*x[i])

    return soma

def tf9(x):
    D = len(x)
    soma = 0
    w = lambda i : 1 + (x[i] - 1)/4
    for i in range(D-1):
        soma += (w(i) - 1)**2 * (1 + 10*np.sin(np.pi*w(i) + 1)**2)

    return np.sin(np.pi*w(1))**2 + soma + w(D-1)**2*(1 + np.sin(2*np.pi*w(D-1))**2)

def tf10(x):
    return np.sin(3*np.pi*x[0])**2 + (x[0] - 1)**2*(1 + np.sin(3*np.pi*x[1])**2) + (x[1] - 1)**2*(1 + np.sin(2*np.pi*x[1])**2)
