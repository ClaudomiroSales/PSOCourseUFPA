# %% [markdown]
# Índice

# %% [markdown]
# - [Data imputation](#Data-imputation)
# - [GADBA](#GADBA)
# - [AG para identificação de regras](#AG-para-identificação-de-regras)
# - [SAPSO](#SAPSO)
# - [Estudos de mecanismo de convergência do PSO](#Estudos-de-mecanismo-de-convergência-do-PSO)

# %%
pathFileImages = 'C:/Users/claud/OneDrive/Documentos/PSOAplicações/'



from IPython.display import Image

# %% [markdown]
# # Artigos

# %% [markdown]
# ## Data imputation

# %%
Image(filename = pathFileImages + 'ImputaçãodeDados.png')

# %%
Image(filename = pathFileImages + 'ImputaçãodeDadosChromossome.png')

# %%
Image(filename = pathFileImages + 'ImputaçãodeDadosWilcoxon.png')

# %% [markdown]
# ## GADBA

# %%
#GADBA #AplicaçõesCompEvol

# %%
Image(filename = pathFileImages + 'GADBA.png')

# %% [markdown]
# ## AG para identificação de regras

# %%
Image(filename = pathFileImages + 'Identificação de Regras.png')

# %%
Image(filename = pathFileImages + 'Identificação de RegrasBase.png')

# %%
Image(filename = pathFileImages + 'Identificação de RegrasChromossome.png')

# %% [markdown]
# ## SAPSO

# %%
Image(filename = pathFileImages + 'SAPSO.png')

# %% [markdown]
# ## Estudos de mecanismo de convergência do PSO

# %%
Image(filename = pathFileImages + 'SAPSO2Art.png')
